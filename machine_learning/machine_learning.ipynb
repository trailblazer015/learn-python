# %% [markdown]
# <a href="https://colab.research.google.com/github/trailblazer015/learn-python/blob/data-science-for-quant/machine_learning/machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
delays_df = pd.read_csv('Lots_of_flight_data.csv')
delays_df.dropna(inplace=True)
delays_df.shape
# Out:
# (290930, 16)

# %%
#飞行距离和飞行时间
X=delays_df.loc[:,['DISTANCE','CRS_ELAPSED_TIME']]
X.head()
# Out:
#    DISTANCE  CRS_ELAPSED_TIME
# 0    1670.0             225.0
# 1    1670.0             225.0
# 2     580.0             105.0
# 3     580.0             105.0
# 4     580.0             100.0

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 290930 entries, 0 to 295047
# Data columns (total 2 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   DISTANCE          290930 non-null  float64
#  1   CRS_ELAPSED_TIME  290930 non-null  float64
# dtypes: float64(2)
# memory usage: 6.7 MB

# %%
#晚点时间
y=delays_df.loc[:,['ARR_DELAY']]
y.head()
# Out:
#    ARR_DELAY
# 0      -17.0
# 1      -25.0
# 2      -13.0
# 3      -12.0
# 4       -7.0

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 290930 entries, 0 to 295047
# Data columns (total 1 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   ARR_DELAY  290930 non-null  float64
# dtypes: float64(1)
# memory usage: 4.4 MB

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42)

# %%
X_train.shape
# Out:
# (203651, 2)

# %%
X_test.shape
# Out:
# (87279, 2)

# %%
X_train.head()
# Out:
#         DISTANCE  CRS_ELAPSED_TIME
# 291460    2402.0             331.0
# 160350     350.0              81.0
# 169835    1096.0             199.0
# 5662      2611.0             342.0
# 93740      223.0              60.0

# %%
y_train.head()
# Out:
#         ARR_DELAY
# 291460       78.0
# 160350       -5.0
# 169835      -38.0
# 5662        -20.0
# 93740       -10.0

# %%
  from sklearn.linear_model import LinearRegression
  regressor=LinearRegression()
  regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(X_test)

# %%
#root mean square value
from sklearn.metrics import mean_squared_error
import numpy as np
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
print(rmse)
# Out:
# 46.61492991528989

# %%
type(y_pred)
# Out:
# numpy.ndarray

# %%
predicted_df=pd.DataFrame(y_pred)
type(predicted_df)
# Out:
# pandas.core.frame.DataFrame

# %%
predicted_df.head()
# Out:
#           0
# 0  5.939224
# 1  6.004687
# 2  6.036628
# 3  3.683718
# 4  5.559619

# %%
X=delays_df.loc[:,['ARR_DELAY']]
y=delays_df.loc[:,['ARR_DELAY']]
X_train,X_test,y_train,y_test=train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42)

regressor.fit(X_train,y_train)
y_pred=regressor.predict(X_test)

# %%
import matplotlib.pyplot as plt
plt.xlabel('DEP_DELAY')
plt.ylabel('ARR_DELAY')
plt.plot(
    X_test,
    y_pred,
    color='red',
    linewidth=2
    )
plt.scatter(
        x=delays_df['DEP_DELAY'],
        y=delays_df['ARR_DELAY'],
        color='blue',
        alpha=0.3
        )
plt.show()
