# %% [markdown]
# <a href="https://colab.research.google.com/github/trailblazer015/learn-python/blob/data-science-for-quant/pandas/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# series

# %%
airports=pd.Series(['Daxing','Chopin','Marco Polo'])
airports
# Out:
# Daxing
# Chopin
# Marco Polo
# 0        Daxing
# 1        Chopin
# 2    Marco Polo
# dtype: object

# %%
for value in airports:
    print(value)
# Out:
# Daxing
# Chopin
# Marco Polo

# %%
airports[2]
# Out:
# 'Marco Polo'

# %% [markdown]
# dataframe

# %%
airports=pd.DataFrame([
    ['Daxing','Beijing','China'],
    ['Chopin','Warsaw','Polad'],
     ['Marco Polo','Venice','Italy']
    ])
airports
# Out:
#             0        1      2
# 0      Daxing  Beijing  China
# 1      Chopin   Warsaw  Polad
# 2  Marco Polo   Venice  Italy

# %%
airports=pd.DataFrame([
    ['Daxing','Beijing','China'],
    ['Chopin','Warsaw','Polad'],
    ['Marco Polo','Venice','Italy']
    ],
    columns=['Airport','City','Country']
    )
airports
# Out:
#       Airport     City Country
# 0      Daxing  Beijing   China
# 1      Chopin   Warsaw   Polad
# 2  Marco Polo   Venice   Italy

# %%
airports.head(2)
# Out:
#   Airport     City Country
# 0  Daxing  Beijing   China
# 1  Chopin   Warsaw   Polad

# %%
airports.tail(2)
# Out:
#       Airport    City Country
# 1      Chopin  Warsaw   Polad
# 2  Marco Polo  Venice   Italy

# %%
airports.shape
# Out:
# (3, 3)

# %%
airports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Airport  3 non-null      object
#  1   City     3 non-null      object
#  2   Country  3 non-null      object
# dtypes: object(3)
# memory usage: 204.0+ bytes

# %%
# request a single column
airports['City']
# Out:
# 0    Beijing
# 1     Warsaw
# 2     Venice
# Name: City, dtype: object

# %%
# request a list og columns
airports[['Airport','Country']]
# Out:
#       Airport Country
# 0      Daxing   China
# 1      Chopin   Polad
# 2  Marco Polo   Italy

# %%
# request by position
airports.iloc[0,1]
# Out:
# 'Beijing'

# %%
airports.iloc[0:2,1:3]
# Out:
#       City Country
# 0  Beijing   China
# 1   Warsaw   Polad

# %%
airports.iloc[:,[1,2]]
# Out:
#       City Country
# 0  Beijing   China
# 1   Warsaw   Polad
# 2   Venice   Italy

# %%
airports.loc[:,['City','Country']]
# Out:
#       City Country
# 0  Beijing   China
# 1   Warsaw   Polad
# 2   Venice   Italy
