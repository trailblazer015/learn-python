# %% [markdown]
# <a href="https://colab.research.google.com/github/trailblazer015/learn-python/blob/data-science-for-quant/pandas/read_write_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
airports_df=pd.read_csv('airports.csv')
airports_df
# Out:
#       Airport     City Country
# 0      Daxing  Beijing   China
# 1      Chopin   Warsaw  Poland
# 2  Marco polo   Venice   Italy

# %%
airports_df=pd.read_csv('airports.csv',header=None)
airports_df
# Out:
#             0        1        2
# 0     Airport     City  Country
# 1      Daxing  Beijing    China
# 2      Chopin   Warsaw   Poland
# 3  Marco polo   Venice    Italy

# %%
airports_df=pd.read_csv('airports.csv',header=None,
            names=['column1','column2','column3']
            )
airports_df
# Out:
#       column1  column2  column3
# 0     Airport     City  Country
# 1      Daxing  Beijing    China
# 2      Chopin   Warsaw   Poland
# 3  Marco polo   Venice    Italy

# %%
airports_df.to_csv(
    'airports_new.csv',
    index=False
    )
